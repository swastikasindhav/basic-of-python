# %%
import pandas as pd
import numpy as np

# %%
bureau=pd.read_csv(r'E:\amex_dataset\data_set_3_m\bureau.csv')
# Out:
# C:\Users\swast\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bureau.head(10)
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      166497       5000002        Closed      currency 1         -149
# 1      166497       5000003        Closed      currency 1         -135
# 2      166497       5000004        Active      currency 1          -47
# 3      356385       5000005        Active      currency 1         -459
# 4      375916       5000009        Closed      currency 1        -2581
# 5      375916       5000010        Closed      currency 1         -352
# 6      375916       5000011        Active      currency 1          -20
# 7      375916       5000012        Active      currency 1         -537
# 8      101767       5000013        Active      currency 1         -256
# 9      101767       5000015        Closed      currency 1        -2571
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0                -26.0              -26.0
# ...

# %%
bureau.columns
# Out:
# Index(['SK_ID_CURR', 'SK_ID_BUREAU', 'CREDIT_ACTIVE', 'CREDIT_CURRENCY',
#        'DAYS_CREDIT', 'CREDIT_DAY_OVERDUE', 'DAYS_CREDIT_ENDDATE',
#        'DAYS_ENDDATE_FACT', 'AMT_CREDIT_MAX_OVERDUE', 'CNT_CREDIT_PROLONG',
#        'AMT_CREDIT_SUM', 'AMT_CREDIT_SUM_DEBT', 'AMT_CREDIT_SUM_LIMIT',
#        'AMT_CREDIT_SUM_OVERDUE', 'CREDIT_TYPE', 'DAYS_CREDIT_UPDATE',
#        'AMT_ANNUITY', 'Unnamed: 17', 'total amount borrowed', 'term '],
#       dtype='object')

# %%
bureau.describe()
# Out:
#          SK_ID_CURR  SK_ID_BUREAU   DAYS_CREDIT  CREDIT_DAY_OVERDUE  \
# count  1.048575e+06  1.048575e+06  1.048575e+06        1.048575e+06
# mean   2.780786e+05  5.899020e+06 -1.134568e+03        8.221815e-01
# std    1.028984e+05  5.342849e+05  7.920656e+02        3.666212e+01
# min    1.000010e+05  5.000002e+06 -2.922000e+03        0.000000e+00
# 25%    1.888150e+05  5.458950e+06 -1.653000e+03        0.000000e+00
# 50%    2.778650e+05  5.929089e+06 -9.800000e+02        0.000000e+00
# 75%    3.671900e+05  6.369406e+06 -4.690000e+02        0.000000e+00
# max    4.562550e+05  6.837603e+06  0.000000e+00        2.781000e+03
#
#        DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  AMT_CREDIT_MAX_OVERDUE  \
# count        983456.000000      659267.000000            3.577400e+05
# mean            537.020756       -1009.273096            4.186821e+03
# std            5032.472137         711.882812            2.605564e+05
# min          -42042.000000      -42023.000000            0.000000e+00
# ...

# %%
bureau.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 20 columns):
# SK_ID_CURR                1048575 non-null int64
# SK_ID_BUREAU              1048575 non-null int64
# CREDIT_ACTIVE             1048575 non-null object
# CREDIT_CURRENCY           1048575 non-null object
# DAYS_CREDIT               1048575 non-null int64
# CREDIT_DAY_OVERDUE        1048575 non-null int64
# DAYS_CREDIT_ENDDATE       983456 non-null float64
# DAYS_ENDDATE_FACT         659267 non-null float64
# AMT_CREDIT_MAX_OVERDUE    357740 non-null float64
# CNT_CREDIT_PROLONG        1048575 non-null int64
# AMT_CREDIT_SUM            1048568 non-null float64
# AMT_CREDIT_SUM_DEBT       891240 non-null float64
# AMT_CREDIT_SUM_LIMIT      683513 non-null float64
# AMT_CREDIT_SUM_OVERDUE    1048575 non-null float64
# CREDIT_TYPE               1048575 non-null object
# DAYS_CREDIT_UPDATE        1048575 non-null int64
# AMT_ANNUITY               319133 non-null float64
# ...

# %%
M=bureau.loc[bureau["CREDIT_ACTIVE"]=="CLOSED","DAYS_CREDIT_ENDDATE"]
print (M)
# Out:
# Series([], Name: DAYS_CREDIT_ENDDATE, dtype: float64)

# %%
bureau.describe(include=np.object)
# Out:
#        CREDIT_ACTIVE CREDIT_CURRENCY      CREDIT_TYPE    term
# count        1048575         1048575          1048575        1
# unique             4               4               15        1
# top           Closed      currency 1  Consumer credit  #DIV/0!
# freq          657173         1047707           763678        1

# %%
bureau.shape
# Out:
# (1048575, 20)

# %%
bureau["CREDIT_TYPE"].value_counts()
# Out:
# Consumer credit                                 763678
# Credit card                                     245977
# Car loan                                         17076
# Mortgage                                         11308
# Microloan                                         8007
# Loan for business development                     1195
# Another type of loan                               641
# Loan for working capital replenishment             311
# Unknown type of loan                               309
# Cash loan (non-earmarked)                           35
# Real estate loan                                    20
# Loan for the purchase of equipment                  13
# Loan for purchase of shares (margin lending)         3
# Interbank credit                                     1
# Mobile operator loan                                 1
# Name: CREDIT_TYPE, dtype: int64

# %%
bureau["CREDIT_ACTIVE"].value_counts()
# Out:
# Closed      657173
# Active      387403
# Sold          3987
# Bad debt        12
# Name: CREDIT_ACTIVE, dtype: int64

# %%
bureau.loc[bureau["CREDIT_TYPE"]=="Mortgage","CREDIT_ACTIVE"].value_counts()
# Out:
# Active    7926
# Closed    2999
# Sold       383
# Name: CREDIT_ACTIVE, dtype: int64

# %%
TOTAL_BORROWED_AMT=bureau['AMT_CREDIT_SUM']+bureau['AMT_CREDIT_SUM_DEBT']

# %%
TOTAL_BORROWED_AMT
# Out:
# 0            13455.000
# 1            37350.000
# 2           630255.240
# 3           354505.500
# 4          1350000.000
# 5            22500.000
# 6            56025.000
# 7           573979.500
# 8           135000.000
# 9                  NaN
# 10          116995.500
# 11          511363.620
# 12          135000.000
# 13          179730.000
# 14           34650.000
# 15          111100.500
# 16                 NaN
# 17            4500.000
# 18         1484221.500
# 19          292500.000
# 20          815706.000
# 21           75802.500
# 22           30928.500
# 23           62532.000
# 24           55125.000
# 25          843457.500
# 26           90363.285
# 27          562500.000
# 28           94320.000
# 29          450000.000
#               ...
# 1048545     288058.500
# 1048546      97848.000
# 1048547    4193338.500
# 1048548      71460.000
# 1048549      67500.000
# 1048550     150750.000
# 1048551     225000.000
# 1048552    1645974.000
# 1048553     294986.970
# ...

# %%
data_with_default=bureau.copy()
data_with_default["AMT_CREDIT_SUM_DEBT"].describe()
value=0
inplace=True

# %%
data_with_default
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0            166497       5000002        Closed      currency 1         -149
# 1            166497       5000003        Closed      currency 1         -135
# 2            166497       5000004        Active      currency 1          -47
# 3            356385       5000005        Active      currency 1         -459
# 4            375916       5000009        Closed      currency 1        -2581
# 5            375916       5000010        Closed      currency 1         -352
# 6            375916       5000011        Active      currency 1          -20
# 7            375916       5000012        Active      currency 1         -537
# 8            101767       5000013        Active      currency 1         -256
# 9            101767       5000015        Closed      currency 1        -2571
# 10           101767       5000017        Closed      currency 1        -1679
# ...

# %%
bureau=bureau.fillna(0)

# %%
TOTAL_BORROWED_AMT=bureau['AMT_CREDIT_SUM']+bureau['AMT_CREDIT_SUM_DEBT']
TOTAL_BORROWED_AMT
# Out:
# 0            13455.000
# 1            37350.000
# 2           630255.240
# 3           354505.500
# 4          1350000.000
# 5            22500.000
# 6            56025.000
# 7           573979.500
# 8           135000.000
# 9           137412.000
# 10          116995.500
# 11          511363.620
# 12          135000.000
# 13          179730.000
# 14           34650.000
# 15          111100.500
# 16          545337.000
# 17            4500.000
# 18         1484221.500
# 19          292500.000
# 20          815706.000
# 21           75802.500
# 22           30928.500
# 23           62532.000
# 24           55125.000
# 25          843457.500
# 26           90363.285
# 27          562500.000
# 28           94320.000
# 29          450000.000
#               ...
# 1048545     288058.500
# 1048546      97848.000
# 1048547    4193338.500
# 1048548      71460.000
# 1048549      67500.000
# 1048550     150750.000
# 1048551     225000.000
# 1048552    1645974.000
# 1048553     294986.970
# ...

# %%
a= bureau['AMT_CREDIT_SUM']-bureau['AMT_CREDIT_SUM_DEBT']
a.sort_values()
# Out:
# 562939     -37137690.0
# 310276     -21885939.0
# 300324     -20441605.5
# 788479     -19389753.0
# 855179     -19089328.5
# 970516     -19063872.0
# 781248     -18121243.5
# 514159     -16803279.0
# 727666     -15484041.0
# 483854     -14919610.5
# 920859     -14243899.5
# 642200     -14135440.5
# 622646     -12771706.5
# 583997     -12418425.0
# 400250     -12121528.5
# 724125     -11542162.5
# 766137     -11254765.5
# 995294     -11134246.5
# 127155     -10958053.5
# 1023605    -10838956.5
# 864459     -10811434.5
# 1043933    -10764009.0
# 749543     -10322370.0
# 1022928     -9512410.5
# 996365      -9483453.0
# 870036      -9431842.5
# 830961      -9212773.5
# 918154      -9210105.0
# 983797      -9040594.5
# 966617      -8594230.5
#               ...
# 138799      38167200.0
# 269239      39060000.0
# 858544      39500820.0
# 203501      40455000.0
# 1025200     45000000.0
# 93104       45000000.0
# 398692      45000000.0
# 278741      47250000.0
# 405102      49662000.0
# ...

# %% [markdown]
# # now working on the instalment payment data

# %%
instalment=pd.read_csv(r'E:\amex_dataset\data_set_3_m\installments_payments.csv')

# %%
instalment.columns
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'NUM_INSTALMENT_VERSION',
#        'NUM_INSTALMENT_NUMBER', 'DAYS_INSTALMENT', 'DAYS_ENTRY_PAYMENT',
#        'AMT_INSTALMENT', 'AMT_PAYMENT'],
#       dtype='object')

# %%
instalment.describe()
# Out:
#          SK_ID_PREV    SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# count  1.048575e+06  1.048575e+06            1.048575e+06
# mean   1.902078e+06  1.501689e+05            8.533371e-01
# std    5.359961e+05  2.892700e+04            9.968260e-01
# min    1.000001e+06  1.000020e+05            0.000000e+00
# 25%    1.431603e+06  1.251470e+05            0.000000e+00
# 50%    1.896367e+06  1.501540e+05            1.000000e+00
# 75%    2.366823e+06  1.753250e+05            1.000000e+00
# max    2.843491e+06  1.999990e+05            4.300000e+01
#
#        NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# count           1.048575e+06     1.048575e+06        1.048575e+06
# mean            1.897017e+01    -1.044954e+03       -1.053735e+03
# std             2.686151e+01     8.021605e+02        8.017614e+02
# min             1.000000e+00    -2.922000e+03       -3.071000e+03
# 25%             4.000000e+00    -1.660000e+03       -1.668000e+03
# ...

# %%
ins=instalment.fillna(0)

# %%
ins.head(5)
# Out:
#    SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  NUM_INSTALMENT_NUMBER  \
# 0     1000001      158271                       1                      1
# 1     1000002      101962                       2                      4
# 2     1000005      176456                       1                      8
# 3     1000005      176456                       1                      2
# 4     1000008      152059                       1                      6
#
#    DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  AMT_INSTALMENT  AMT_PAYMENT
# 0             -268                -294        6404.310     6404.310
# 1            -1510               -1554       18443.565    18443.565
# 2            -1478               -1484       14713.605    14713.605
# 3            -1658               -1664       14713.605    14713.605
# 4            -1132               -1173       26331.660    26331.660

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 8 columns):
# SK_ID_PREV                1048575 non-null int64
# SK_ID_CURR                1048575 non-null int64
# NUM_INSTALMENT_VERSION    1048575 non-null int64
# NUM_INSTALMENT_NUMBER     1048575 non-null int64
# DAYS_INSTALMENT           1048575 non-null int64
# DAYS_ENTRY_PAYMENT        1048575 non-null int64
# AMT_INSTALMENT            1048575 non-null float64
# AMT_PAYMENT               1048575 non-null float64
# dtypes: float64(2), int64(6)
# memory usage: 64.0 MB

# %%
ins.head(20)
# Out:
#     SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  NUM_INSTALMENT_NUMBER  \
# 0      1000001      158271                       1                      1
# 1      1000002      101962                       2                      4
# 2      1000005      176456                       1                      8
# 3      1000005      176456                       1                      2
# 4      1000008      152059                       1                      6
# 5      1000011      198678                       1                      9
# 6      1000011      198678                       1                      7
# 7      1000011      198678                       1                      5
# 8      1000016      157990                       1                      4
# 9      1000016      157990                       1                      3
# 10     1000016      157990                       1                      2
# 11     1000019      176905                       1                     10
# ...

# %%
previous_applications=pd.read_csv(r'E:\amex_dataset\data_set_3_m\previous_application.csv')

# %%
previous_applications.columns
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'AMT_ANNUITY',
#        'AMT_APPLICATION', 'AMT_CREDIT', 'AMT_DOWN_PAYMENT', 'AMT_GOODS_PRICE',
#        'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START',
#        'FLAG_LAST_APPL_PER_CONTRACT', 'NFLAG_LAST_APPL_IN_DAY',
#        'RATE_DOWN_PAYMENT', 'RATE_INTEREST_PRIMARY',
#        'RATE_INTEREST_PRIVILEGED', 'NAME_CASH_LOAN_PURPOSE',
#        'NAME_CONTRACT_STATUS', 'DAYS_DECISION', 'NAME_PAYMENT_TYPE',
#        'CODE_REJECT_REASON', 'NAME_TYPE_SUITE', 'NAME_CLIENT_TYPE',
#        'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE',
#        'CHANNEL_TYPE', 'SELLERPLACE_AREA', 'NAME_SELLER_INDUSTRY',
#        'CNT_PAYMENT', 'NAME_YIELD_GROUP', 'PRODUCT_COMBINATION',
#        'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE', 'DAYS_LAST_DUE_1ST_VERSION',
#        'DAYS_LAST_DUE', 'DAYS_TERMINATION', 'NFLAG_INSURED_ON_APPROVAL',
#        'RATE*100', '#NAME?', 'RATE'],
#       dtype='object')

# %%
previous_applications.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     1000001      158271     Consumer loans     6404.310        58905.000
# 1     1000002      101962     Consumer loans     6264.000        39145.500
# 2     1000005      176456     Consumer loans    14713.605       123486.075
# 3     1000008      152059     Consumer loans    26331.660       249255.000
# 4     1000009      343078     Consumer loans     9302.850        42705.000
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     65124.0             0.000        58905.000                   THURSDAY
# 1     35230.5          3915.000        39145.500                     SUNDAY
# 2    120307.5         12349.575       123486.075                   THURSDAY
# 3    224325.0         24930.000       249255.000                     MONDAY
# 4     45243.0             0.000        42705.000                   SATURDAY
#
# ...

# %%
previous_applications['RATE'].value_counts()
# Out:
# 0        396251
# 3        143940
# 2        135927
# 6        105424
# 4         83333
# 5         70248
# #NUM!     61251
# 1         34809
# 7         15380
# 8          1520
# 9           347
# 10          141
# 11            4
# Name: RATE, dtype: int64

# %%
previous_applications['NAME_CONTRACT_STATUS'].value_counts(normalize=True)
# Out:
# Approved        0.622260
# Canceled        0.188094
# Refused         0.173648
# Unused offer    0.015998
# Name: NAME_CONTRACT_STATUS, dtype: float64

# %%
previous_applications.loc[previous_applications["NAME_CONTRACT_STATUS"]=="Approved","RATE"].value_counts(normalize=True)
# Out:
# 3        0.220602
# 2        0.208322
# 6        0.161573
# 4        0.127716
# 5        0.107662
# #NUM!    0.093873
# 1        0.053348
# 7        0.023571
# 8        0.002330
# 9        0.000532
# 0        0.000248
# 10       0.000216
# 11       0.000006
# Name: RATE, dtype: float64

# %%
previous_applications["NAME_CONTRACT_TYPE"].value_counts()
# Out:
# Cash loans         465861
# Consumer loans     461049
# Revolving loans    121441
# XNA                   224
# Name: NAME_CONTRACT_TYPE, dtype: int64

# %%
previous_applications.loc[previous_applications["NAME_CONTRACT_TYPE"]=="Cash loans","RATE"].value_counts(normalize=True)
# Out:
# 0        0.580693
# 3        0.117365
# 2        0.101311
# 4        0.097400
# 5        0.065049
# 6        0.036717
# 1        0.001455
# #NUM!    0.000006
# 7        0.000002
# Name: RATE, dtype: float64

# %%
previous_applications.loc[previous_applications["NAME_CONTRACT_TYPE"]=="Consumer loans","RATE"].value_counts(normalize=True)
# Out:
# 3        0.193611
# 2        0.192452
# 6        0.191561
# 0        0.141653
# 5        0.086637
# 4        0.082330
# 1        0.074029
# 7        0.033357
# 8        0.003297
# 9        0.000753
# 10       0.000306
# 11       0.000009
# #NUM!    0.000007
# Name: RATE, dtype: float64

# %%
previous_applications.loc[previous_applications["NAME_CONTRACT_TYPE"]=="Revolving loans","RATE"].value_counts()
# Out:
# #NUM!    61245
# 0        60196
# Name: RATE, dtype: int64

# %%
m=pd.merge(previous_applications,ins)

# %%
m.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     1000001      158271     Consumer loans     6404.310        58905.000
# 1     1000002      101962     Consumer loans     6264.000        39145.500
# 2     1000005      176456     Consumer loans    14713.605       123486.075
# 3     1000005      176456     Consumer loans    14713.605       123486.075
# 4     1000008      152059     Consumer loans    26331.660       249255.000
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     65124.0             0.000        58905.000                   THURSDAY
# 1     35230.5          3915.000        39145.500                     SUNDAY
# 2    120307.5         12349.575       123486.075                   THURSDAY
# 3    120307.5         12349.575       123486.075                   THURSDAY
# 4    224325.0         24930.000       249255.000                     MONDAY
#
# ...

# %%
    POS=pd.read_csv(r'E:\amex_dataset\data_set_3_m\POS_CASH_balance.csv')

# %%
import statistics as st 
import seaborn as sb

# %%
 S= previous_applications.loc[previous_applications["NAME_CONTRACT_TYPE"]=="Consumer loans"]
S.describe()
# Out:
#          SK_ID_PREV     SK_ID_CURR    AMT_ANNUITY  AMT_APPLICATION  \
# count  4.610490e+05  461049.000000  437122.000000     4.610490e+05
# mean   1.906881e+06  278414.661578   10134.754863     9.383630e+04
# std    5.353332e+05  102829.398333    8324.455663     1.027818e+05
# min    1.000001e+06  100001.000000     579.780000     0.000000e+00
# 25%    1.439529e+06  189472.000000    5045.501250     3.798900e+04
# 50%    1.898350e+06  278554.000000    7969.950000     6.839550e+04
# 75%    2.370795e+06  367578.000000   12573.630000     1.165500e+05
# max    2.845382e+06  456255.000000  393868.665000     6.905160e+06
#
#          AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE  \
# count  4.610490e+05      4.578330e+05     4.601830e+05
# mean   9.157878e+04      7.148043e+03     9.401289e+04
# std    9.663512e+04      2.140428e+04     1.027978e+05
# min    0.000000e+00     -9.000000e-01     0.000000e+00
# 25%    3.592800e+04      0.000000e+00     3.816000e+04
# ...

# %%
previous_applications=previous_applications.dropna(how='all')
previous_applications.drop(previous_applications[previous_applications['RATE']=="#NUM!"].index,inplace=True)

# %%
previous_applications.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 987324 entries, 0 to 1048574
# Data columns (total 40 columns):
# SK_ID_PREV                     987324 non-null int64
# SK_ID_CURR                     987324 non-null int64
# NAME_CONTRACT_TYPE             987324 non-null object
# AMT_ANNUITY                    754321 non-null float64
# AMT_APPLICATION                987324 non-null float64
# AMT_CREDIT                     987324 non-null float64
# AMT_DOWN_PAYMENT               488543 non-null float64
# AMT_GOODS_PRICE                773090 non-null float64
# WEEKDAY_APPR_PROCESS_START     987324 non-null object
# HOUR_APPR_PROCESS_START        987324 non-null int64
# FLAG_LAST_APPL_PER_CONTRACT    987324 non-null object
# NFLAG_LAST_APPL_IN_DAY         987324 non-null int64
# RATE_DOWN_PAYMENT              488543 non-null float64
# RATE_INTEREST_PRIMARY          3720 non-null float64
# RATE_INTEREST_PRIVILEGED       3720 non-null float64
# ...

# %%
previous_applications['RATE'].astype(str).astype(int)
# Out:
# 0          3
# 1          2
# 2          4
# 3          3
# 4          6
# 5          4
# 6          3
# 7          4
# 8          2
# 9          5
# 10         6
# 11         2
# 12         4
# 13         3
# 14         2
# 16         2
# 18         6
# 19         3
# 20         5
# 21         5
# 22         2
# 23         2
# 24         2
# 25         1
# 26         3
# 27         3
# 28         4
# 29         3
# 30         6
# 31         8
#           ..
# 1048545    0
# 1048546    0
# 1048547    0
# 1048548    0
# 1048549    0
# 1048550    0
# 1048551    0
# 1048552    0
# 1048553    0
# 1048554    0
# 1048555    0
# 1048556    0
# 1048557    0
# 1048558    0
# 1048559    0
# 1048560    0
# 1048561    0
# 1048562    0
# 1048563    0
# 1048564    0
# 1048565    0
# 1048566    0
# 1048567    0
# 1048568    0
# 1048569    0
# 1048570    0
# 1048571    0
# 1048572    0
# 1048573    0
# 1048574    0
# Name: RATE, Length: 987324, dtype: int32

# %%
previous_applications['RATE'].value_counts()
# Out:
# 0     396251
# 3     143940
# 2     135927
# 6     105424
# 4      83333
# 5      70248
# 1      34809
# 7      15380
# 8       1520
# 9        347
# 10       141
# 11         4
# Name: RATE, dtype: int64

# %%
previous_applications.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 987324 entries, 0 to 1048574
# Data columns (total 40 columns):
# SK_ID_PREV                     987324 non-null int64
# SK_ID_CURR                     987324 non-null int64
# NAME_CONTRACT_TYPE             987324 non-null object
# AMT_ANNUITY                    754321 non-null float64
# AMT_APPLICATION                987324 non-null float64
# AMT_CREDIT                     987324 non-null float64
# AMT_DOWN_PAYMENT               488543 non-null float64
# AMT_GOODS_PRICE                773090 non-null float64
# WEEKDAY_APPR_PROCESS_START     987324 non-null object
# HOUR_APPR_PROCESS_START        987324 non-null int64
# FLAG_LAST_APPL_PER_CONTRACT    987324 non-null object
# NFLAG_LAST_APPL_IN_DAY         987324 non-null int64
# RATE_DOWN_PAYMENT              488543 non-null float64
# RATE_INTEREST_PRIMARY          3720 non-null float64
# RATE_INTEREST_PRIVILEGED       3720 non-null float64
# ...

# %%
sb.distplot(previous_applications['RATE'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-67b80ae82baf> in <module>
# ----> 1 sb.distplot(previous_applications['RATE'])
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     196             line, = ax.plot(0, a.mean())
#     197         else:
# --> 198             line, = ax.plot(a.mean(), 0)
#     199         color = line.get_color()
#     200         line.remove()
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      85             ret = ret.dtype.type(ret / rcount)
#      86     else:
# ---> 87         ret = ret / rcount
#      88
#      89     return ret
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
rate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-11cd706e573c> in <module>
# ----> 1 rate
#
# NameError: name 'rate' is not defined
